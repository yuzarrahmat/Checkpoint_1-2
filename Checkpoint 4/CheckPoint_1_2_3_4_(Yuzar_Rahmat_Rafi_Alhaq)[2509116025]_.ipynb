# %% [markdown]
# # Restaurant Sales Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "/content/drive/MyDrive/COLAB YUZAR/restaurant_sales_data.csv"
df = pd.read_csv(file)

df
# Out:
#          Order ID Customer ID     Category             Item  Price  Quantity  \
# 0      ORD_705844    CUST_092  Side Dishes       Side Salad    3.0       1.0
# 1      ORD_338528    CUST_021  Side Dishes  Mashed Potatoes    4.0       3.0
# 2      ORD_443849    CUST_029  Main Dishes  Grilled Chicken   15.0       4.0
# 3      ORD_630508    CUST_075       Drinks              NaN    NaN       2.0
# 4      ORD_648269    CUST_031  Main Dishes    Pasta Alfredo   12.0       4.0
# ...           ...         ...          ...              ...    ...       ...
# 17529  ORD_320102    CUST_021       Drinks              NaN    NaN       4.0
# 17530  ORD_974128    CUST_069     Desserts        Ice Cream    5.0       3.0
# 17531  ORD_108324    CUST_050     Desserts        Ice Cream    5.0       4.0
# 17532  ORD_612647    CUST_073  Side Dishes  Mashed Potatoes    4.0       2.0
# 17533  ORD_680707    CUST_006     Desserts              NaN    7.0       4.0
#
#        Order Total  Order Date  Payment Method
# 0              3.0  2023-12-21     Credit Card
# 1             12.0  2023-05-19  Digital Wallet
# 2             60.0  2023-09-27     Credit Card
# 3              5.0  2022-08-09     Credit Card
# 4             48.0  2022-05-15            Cash
# ...            ...         ...             ...
# 17529          4.0  2023-12-23            Cash
# 17530         15.0  2023-12-18            Cash
# 17531         20.0  2022-05-20  Digital Wallet
# 17532          8.0  2022-01-27  Digital Wallet
# 17533         28.0  2023-01-07             NaN
#
# [17534 rows x 9 columns]

# %% [markdown]
# # Business Understanding

# %% [markdown]
# ## Business Objective

# %% [markdown]
# Kita memiliki dataset transaksi restoran dari tahun 2022-2023. Terdapat order id, customer id, kategori menu, item, harga, jumlah, total, tanggal, dan metode bayar. Tujuannya adalah mencari tahu pola penjualan agar dapat memberikan masukan ke restoran, seperti:
#
# - Menu apa yang paling laris?
# - Kapan waktu ramai pengunjung?
# - Metode pembayaran apa yang paling sering dipakai?
# - Apakah ada hubungan antara harga dan jumlah yang dibeli?
#
# Dari hasil analisis, restoran dapat mengatur stok lebih baik, bikin promo pas waktu sepi, dan meningkatin pelayanan.

# %% [markdown]
# ## Assess Situation

# %% [markdown]
# Saat ini, restoran memiliki data transaksi yang cukup lengkap namun terdapat beberapa masalah:
#
# - Terdapat kolom yang kosong (missing values), terutama di kolom Item, Price, Quantity, Order Total, dan Payment Method.
#
# - Format tanggal yang sudah bagus, tetapi perlu dipisah jadi bulan/tahun agar mudah dianalisis.
#
# Banyaknya missing values dapat mengurangi keandalan hasil jika tidak ditangani dengan baik.

# %% [markdown]
# ## Analytic Goals

# %% [markdown]
# - Mengidentifikasi kategori dan item dengan penjualan tertinggi dan kontribusi pendapatan terbesar.
# - Mengetahui pola penjualan harian, bulanan, dan tahunan untuk menentukan periode sibuk dan sepi.
# - Menganalisis metode pembayaran yang paling sering digunakan dan kaitannya dengan nilai transaksi.
# - Melihat hubungan antara harga, jumlah pesanan, dan total penjualan untuk menentukan strategi harga.
# - Menemukan transaksi tidak wajar (misal, missing values atau outlier) untuk perbaikan data.

# %% [markdown]
# ## Project Plan

# %% [markdown]
# - Data Understanding dan Preparation
# - Eksplorasi Data dan Visualisasi
# - Analisis dan Kesimpulan

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Informasi Lanjutan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17534 entries, 0 to 17533
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        17534 non-null  object
#  1   Customer ID     17534 non-null  object
#  2   Category        17534 non-null  object
#  3   Item            15776 non-null  object
#  4   Price           16658 non-null  float64
#  5   Quantity        17104 non-null  float64
#  6   Order Total     17104 non-null  float64
#  7   Order Date      17534 non-null  object
#  8   Payment Method  16452 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 1.2+ MB

# %% [markdown]
# 1. Order ID: Jumlah Baris: 17534 Tipe Data: object Deskripsi: ID Pesanan
# 2. Customer ID: Jumlah Baris: 17534 Tipe Data: object Deskripsi: ID Pembeli
# 3. Category: Jumlah Baris: 17534 Tipe Data: object Deskripsi: Kategori
# 4. Item: Jumlah Baris: 15776 Tipe Data: object Deskripsi: Barang
# 5. Price: Jumlah Baris: 16658 Tipe Data: float64 Deskripsi: Harga
# 6. Quantity: Jumlah Baris: 17104 Tipe Data: float64 Deskripsi : Jumlah
# 7. Order Total: Jumlah Baris: 17104 Tipe Data: float64 Deskripsi : Jumlah Pesanan
# 8. Order Date: Jumlah Baris: 17534 Tipe Data: object Deskripsi : Tanggal Pesanan
# 9. Payment Method: Jumlah Baris: 16452 Tipe Data: object Deskripsi : Metode Pembayaran

# %% [markdown]
# ## Statistik Deskriptif

# %%
df.describe(include='all')
# Out:
#           Order ID Customer ID     Category           Item         Price  \
# count        17534       17534        17534          15776  16658.000000
# unique       17534         100            5             26           NaN
# top     ORD_680707    CUST_066  Main Dishes  Pasta Alfredo           NaN
# freq             1         207         3551            998           NaN
# mean           NaN         NaN          NaN            NaN      6.586325
# std            NaN         NaN          NaN            NaN      4.834652
# min            NaN         NaN          NaN            NaN      1.000000
# 25%            NaN         NaN          NaN            NaN      3.000000
# 50%            NaN         NaN          NaN            NaN      5.000000
# 75%            NaN         NaN          NaN            NaN      7.000000
# max            NaN         NaN          NaN            NaN     20.000000
#
#             Quantity   Order Total  Order Date Payment Method
# count   17104.000000  17104.000000       17534          16452
# unique           NaN           NaN         730              3
# top              NaN           NaN  2023-11-25    Credit Card
# freq             NaN           NaN          42           5504
# mean        3.014149     19.914494         NaN            NaN
# std         1.414598     18.732549         NaN            NaN
# min         1.000000      1.000000         NaN            NaN
# 25%         2.000000      7.500000         NaN            NaN
# 50%         3.000000     15.000000         NaN            NaN
# 75%         4.000000     25.000000         NaN            NaN
# max         5.000000    100.000000         NaN            NaN

# %% [markdown]
# 1. Count (Kelengkapan Data)
# Berdasarkan data, total baris transaksi adalah 155. Maka dapat disimpulkan:
# * Item hilang 1758 data (17534 - 15776)
# * Price hilang 876 data (17534 - 16658)
# * Quantity hilang 430 data (17534 - 17104)
# * Order Total hilang 430 data (17534 - 17104)
# * Payment Method hilang 1082 data (17534 - 16452)
#
# Kesimpulan: Kolom Item, Price, Quantity, Order Total, dan Payment Method mengandung missing values, sementara kolom lainnya sudah lengkap (17534 data)
#
#
#
# ---
#
#
#
# 2. Mean vs Median (Distribusi Data)
#
# * Kolom Price
#   * Mean = 6.59
#   * Median = 5.0 - Nilai rata-rata sedikit lebih besar dari median
#
#   Perbedaan yang signifikan antara mean dan median menunjukkan bahwa distribusi harga cenderung condong ke kanan (right-skewed), berarti ada beberapa item dengan harga yang jauh lebih tinggi (outlier) yang menarik nilai rata-rata ke atas, sedangkan sebagian besar item memiliki harga yang lebih rendah.
#
# * Kolom Quantity
#  * Mean = 3,01
#  * Median = 3,0 - Rata-rata pembelian hampir sama dengan median
#
#    Ini mengindikasikan bahwa sebagian besar transaksi melibatkan jumlah barang yang serupa, dan tidak ada nilai ekstrem (outlier) yang signifikan mempengaruhi rata-rata.
#
# * Kolom Order Total
#   * Mean = 19,91
#   * Median = 15,0 - Perbedaan yang tidak terlalu jauh antara mean dan median
#
#   berarti ada beberapa transaksi dengan nilai total pesanan yang sangat tinggi (outlier), yang secara signifikan menarik nilai rata-rata ke atas, sementara mayoritas transaksi memiliki nilai total yang jauh lebih rendah.
#
# Kesimpulan: Secara keseluruhan, data bersifat right-skewed (condong ke kanan), di mana terdapat nilai-nilai ekstrem tinggi yang memengaruhi nilai rata-rata di semua variabel utama.
#
#
#
# ---
#
#
#
# 3. Min dan Max (Validasi Logika)
#
# * Price
#   * Min = 1,0
#   * Max = 20,0
#
# * Quantity
#   * Min = 1,0
#   * Max = 5,0
#
# * Order Total
#   * Min = 1,0
#   * Max = 100,0
#
# Kesimpulan:
# * Price: Rentang harga dari 1.0 hingga 20.0 Dolar terlihat wajar untuk item menu restoran.
#
# * Quantity: Jumlah pesanan per transaksi dari 1.0 hingga 5.0 unit       menunjukkan pola pembelian normal, tanpa indikasi pesanan massal yang tidak biasa.
#
# * Order Total: Total pesanan dari 1.0 hingga 100.0 Dolar mencakup pembelian individual kecil hingga pesanan kelompok yang lebih besar, yang merupakan rentang yang logis untuk transaksi restoran.
#
#
#
# ---
#
#
#
# 4. Standar Deviasi (std) - Variabilitas Data
#
# * Price
#   * Mean = 6.59
#   * Std = 4.834
#
# * Quantity
#   * Mean = 3,01
#   * Std = 1,414
#
# * Order Total
#   * Mean = 19,91
#   * Std = 18,732
#
# Kesimpulan:
#
# * Pada kolom Price, nilai standar deviasi yang cukup tinggi relatif terhadap rata-ratanya menunjukkan variasi harga item yang dijual cukup beragam.
#
# * Pada kolom Quantity, nilai standar deviasi yang relatif rendah menunjukkan bahwa jumlah item yang dibeli dalam setiap transaksi tidak terlalu bervariasi; sebagian besar pesanan memiliki jumlah item yang serupa.
#
# * Pada kolom Order Total, nilai standar deviasi yang tinggi menunjukkan variasi yang signifikan dalam nilai total pesanan. Ini mengindikasikan ada perbedaan besar antara total pesanan terendah dan tertinggi, dengan beberapa transaksi yang jauh lebih besar dari rata-rata.

# %% [markdown]
# # Verifikasi Kualitas Data

# %% [markdown]
# ## Cek Tipe Data

# %% [markdown]
# Pada bagian ini, saya akan mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak. Agar insight serta visualisasi yang akan dibuat menjadi akurat. Dapat dilihat dibawah ini, kolom **Order Date** dengan tipe data "object", seharusnya kolom ini bertipe data "date" bukan "object". Selain kolom kolom tersebut, sudah sesuai.

# %%
df.dtypes
# Out:
# Order ID           object
# Customer ID        object
# Category           object
# Item               object
# Price             float64
# Quantity          float64
# Order Total       float64
# Order Date         object
# Payment Method     object
# dtype: object

# %% [markdown]
# ## Inconsistent Values

# %% [markdown]
# Pada bagian ini, saya perlu mengecek kekonsistenan data, agar data tidak terduplikat dengan baris yang sebenarnya sama akan tetapi bisa terduplikat karena penulisannya tidak konsisten.

# %% [markdown]
# 1. Category

# %%
print(df['Category'].unique())
# Out:
# ['Side Dishes' 'Main Dishes' 'Drinks' 'Desserts' 'Starters']

# %% [markdown]
# Untuk Kolom Category, dapat dilihat diatas bahwa data nya sudah konsisten.

# %% [markdown]
# 2. Item

# %%
print(df['Item'].unique())
# Out:
# ['Side Salad' 'Mashed Potatoes' 'Grilled Chicken' nan 'Pasta Alfredo'
#  'Salmon' 'Garlic Bread' 'Vegetarian Platter' 'Brownie'
#  'Sweet Potato Fries' 'Lemonade' 'Orange Juice' 'Chocolate Cake'
#  'Coca Cola' 'Grilled Vegetables' 'Cheese Fries' 'Beef Chili'
#  'Chicken Melt' 'Fruit Salad' 'French Fries' 'Ice Cream' 'Cheesecake'
#  'Iced Tea' 'Water' 'Nachos Grande' 'Onion Rings' 'Steak']

# %% [markdown]
# Untuk kolom Item, dapat dilihat diatas bahwa data nya sudah konsisten.

# %% [markdown]
# 3. Order Date

# %%
print(df['Order Date'].unique())
# Out:
# ['2023-12-21' '2023-05-19' '2023-09-27' '2022-08-09' '2022-05-15'
#  '2022-07-20' '2022-08-19' '2023-02-15' '2023-12-16' '2022-08-07'
#  '2023-12-09' '2023-10-30' '2023-04-11' '2023-08-18' '2022-06-08'
#  '2022-08-28' '2022-05-01' '2023-09-01' '2022-11-13' '2023-06-08'
#  '2023-02-21' '2023-02-01' '2023-05-09' '2023-09-14' '2023-03-18'
#  '2023-05-18' '2023-09-05' '2022-02-02' '2023-07-30' '2023-01-31'
#  '2023-02-28' '2022-11-19' '2023-05-03' '2023-04-20' '2023-09-18'
#  '2022-04-08' '2023-07-29' '2023-10-16' '2022-02-09' '2023-08-17'
#  '2022-04-13' '2023-07-21' '2023-12-03' '2023-09-16' '2023-02-11'
#  '2023-02-05' '2022-01-16' '2023-11-21' '2022-10-08' '2023-03-01'
#  '2023-05-23' '2022-08-11' '2022-08-03' '2022-12-20' '2022-09-12'
#  '2022-06-24' '2023-08-04' '2022-03-11' '2023-09-28' '2022-08-12'
#  '2023-01-23' '2023-07-08' '2022-12-07' '2023-08-01' '2023-06-30'
#  '2022-05-27' '2022-04-07' '2022-10-02' '2023-06-01' '2023-05-24'
#  '2023-04-01' '2023-01-19' '2022-08-18' '2022-01-11' '2022-05-13'
#  '2022-05-29' '2022-07-15' '2023-06-07' '2022-07-08' '2022-10-28'
#  '2022-09-15' '2023-03-30' '2023-04-13' '2022-04-01' '2022-03-28'
#  '2023-01-28' '2022-11-14' '2022-07-27' '2022-05-25' '2023-08-15'
#  '2022-02-05' '2022-02-18' '2023-07-27' '2023-03-10' '2023-05-10'
#  '2022-07-29' '2023-02-26' '2023-03-24' '2023-08-22' '2023-03-09'
#  '2023-06-10' '2023-10-29' '2022-10-14' '2023-11-26' '2022-03-24'
#  '2023-11-22' '2023-01-21' '2022-01-05' '2023-05-26' '2022-09-29'
#  '2022-05-30' '2023-02-13' '2023-08-24' '2022-12-31' '2022-12-09'
#  '2022-01-01' '2023-05-07' '2023-11-10' '2023-04-03' '2022-12-24'
#  '2022-11-22' '2023-04-19' '2022-01-06' '2023-11-30' '2023-04-22'
#  '2022-12-28' '2022-03-27' '2022-03-04' '2023-03-29' '2023-06-18'
#  '2022-06-02' '2022-10-27' '2022-09-22' '2022-10-01' '2022-02-12'
#  '2022-08-15' '2022-04-24' '2023-04-10' '2022-06-28' '2022-06-22'
#  '2023-12-25' '2023-03-14' '2023-11-11' '2023-02-08' '2022-08-06'
#  '2023-12-11' '2022-07-13' '2023-12-08' '2022-06-13' '2023-10-15'
#  '2023-02-07' '2022-02-26' '2022-12-05' '2022-07-22' '2023-06-11'
#  '2023-07-16' '2023-12-07' '2023-05-21' '2022-06-16' '2022-04-16'
#  '2022-12-19' '2023-06-25' '2022-10-13' '2022-10-16' '2023-02-03'
#  '2023-10-11' '2022-11-17' '2022-09-10' '2023-09-08' '2023-11-27'
#  '2022-05-03' '2022-09-26' '2022-05-28' '2022-05-11' '2022-11-26'
#  '2022-04-12' '2023-12-14' '2022-09-16' '2022-11-20' '2023-05-27'
#  '2022-09-03' '2023-06-22' '2023-05-28' '2022-12-06' '2022-04-29'
#  '2022-03-18' '2022-04-11' '2022-07-04' '2023-01-06' '2022-05-14'
#  '2022-12-14' '2022-07-01' '2022-10-03' '2023-10-25' '2022-03-13'
#  '2023-04-27' '2023-05-06' '2023-01-09' '2022-06-27' '2023-02-19'
#  '2023-03-11' '2022-06-20' '2023-04-18' '2022-03-23' '2023-03-19'
#  '2023-06-29' '2022-11-16' '2022-02-07' '2022-02-14' '2023-01-18'
#  '2022-08-31' '2023-01-20' '2023-03-04' '2022-11-29' '2022-07-06'
#  '2023-07-06' '2023-02-18' '2023-04-15' '2022-11-28' '2023-09-26'
#  '2023-11-20' '2023-09-12' '2023-02-04' '2022-12-11' '2022-11-23'
#  '2022-03-15' '2023-08-14' '2023-02-23' '2022-10-21' '2023-04-12'
#  '2022-05-26' '2023-05-31' '2023-11-15' '2022-06-21' '2022-05-05'
#  '2023-06-05' '2023-03-27' '2022-10-05' '2023-10-12' '2023-09-30'
#  '2023-11-25' '2022-01-31' '2023-01-04' '2023-11-05' '2022-08-29'
#  '2023-04-25' '2023-09-22' '2022-03-17' '2023-07-07' '2022-10-11'
#  '2023-05-05' '2023-10-20' '2022-03-29' '2023-07-25' '2022-05-08'
#  '2022-09-09' '2023-07-13' '2023-06-12' '2023-10-06' '2022-11-07'
#  '2022-12-08' '2022-10-20' '2022-04-22' '2022-11-06' '2023-12-30'
#  '2022-04-15' '2022-07-26' '2023-01-16' '2023-08-12' '2023-08-28'
#  '2023-06-19' '2022-01-18' '2023-10-22' '2022-03-26' '2023-09-03'
#  '2022-05-22' '2023-08-25' '2022-10-23' '2023-11-14' '2022-03-21'
#  '2022-03-25' '2023-07-01' '2023-11-19' '2022-10-12' '2022-01-24'
#  '2023-08-10' '2023-09-19' '2022-01-29' '2022-07-17' '2023-06-28'
#  '2022-05-24' '2022-01-15' '2023-10-24' '2023-11-09' '2023-11-13'
#  '2023-02-12' '2023-09-24' '2023-07-23' '2022-09-02' '2022-12-29'
#  '2023-09-29' '2023-05-04' '2022-04-20' '2022-12-21' '2022-07-09'
#  '2023-11-01' '2022-06-29' '2023-03-23' '2023-05-22' '2022-11-30'
#  '2023-04-21' '2022-10-25' '2022-02-08' '2022-11-05' '2022-05-21'
#  '2022-07-24' '2023-10-31' '2022-10-04' '2023-10-18' '2022-07-28'
#  '2022-06-30' '2022-09-20' '2023-05-14' '2022-08-05' '2023-03-22'
#  '2023-04-16' '2022-09-04' '2022-04-03' '2023-02-16' '2022-02-01'
#  '2022-11-27' '2023-07-17' '2023-09-20' '2022-03-01' '2023-09-15'
#  '2023-05-02' '2023-08-02' '2022-07-18' '2022-10-07' '2022-02-10'
#  '2023-11-18' '2022-10-09' '2022-08-26' '2023-12-18' '2023-10-19'
#  '2023-08-06' '2022-10-17' '2023-09-02' '2023-11-04' '2022-03-07'
#  '2022-01-26' '2023-07-10' '2022-02-28' '2023-10-07' '2023-12-02'
#  '2023-06-04' '2022-06-19' '2022-09-01' '2022-04-17' '2022-01-20'
#  '2023-11-29' '2022-02-16' '2022-01-07' '2022-02-25' '2022-08-21'
#  '2022-04-05' '2022-05-09' '2022-06-07' '2023-03-15' '2022-01-13'
#  '2023-12-06' '2023-10-23' '2023-01-26' '2022-03-19' '2022-02-27'
#  '2023-04-17' '2023-05-17' '2023-03-03' '2022-07-02' '2022-04-14'
#  '2022-01-02' '2022-04-06' '2022-04-19' '2022-06-23' '2023-08-23'
#  '2022-07-30' '2022-12-25' '2022-02-15' '2023-06-16' '2023-10-05'
#  '2023-02-09' '2023-08-03' '2023-04-06' '2023-06-17' '2022-11-01'
#  '2023-07-22' '2023-02-25' '2023-08-20' '2023-03-07' '2022-10-10'
#  '2023-08-13' '2023-12-26' '2022-06-06' '2023-06-27' '2023-07-28'
#  '2023-10-28' '2022-11-12' '2022-01-27' '2022-08-01' '2022-05-17'
#  '2022-12-18' '2022-12-16' '2022-06-03' '2023-07-31' '2023-08-29'
#  '2023-09-21' '2022-08-10' '2022-09-11' '2023-03-06' '2022-07-16'
#  '2022-01-08' '2022-03-09' '2023-10-04' '2023-11-12' '2022-03-20'
#  '2022-03-22' '2023-03-02' '2023-05-01' '2022-07-23' '2022-09-08'
#  '2022-10-22' '2023-02-24' '2022-05-12' '2023-12-17' '2022-06-01'
#  '2023-02-22' '2023-11-06' '2022-12-02' '2022-05-23' '2023-01-13'
#  '2023-03-25' '2023-02-17' '2023-07-20' '2022-02-22' '2023-05-30'
#  '2023-06-14' '2022-03-31' '2023-03-08' '2023-07-15' '2023-04-24'
#  '2022-08-08' '2023-10-10' '2022-10-06' '2023-10-26' '2022-09-27'
#  '2022-08-27' '2023-10-09' '2023-10-14' '2023-08-30' '2022-05-18'
#  '2023-03-21' '2023-04-28' '2022-12-03' '2023-06-15' '2022-12-17'
#  '2022-04-02' '2023-11-23' '2022-08-30' '2023-10-02' '2022-05-07'
#  '2022-01-30' '2023-05-20' '2023-12-04' '2022-06-09' '2022-01-03'
#  '2023-12-15' '2022-10-31' '2022-12-22' '2023-09-17' '2022-11-15'
#  '2023-01-11' '2022-07-19' '2022-05-02' '2023-01-17' '2022-09-28'
#  '2022-10-26' '2022-09-06' '2022-07-14' '2023-07-12' '2022-07-11'
#  '2023-03-05' '2022-05-31' '2023-03-28' '2022-04-10' '2023-01-30'
#  '2023-05-08' '2022-11-09' '2022-08-20' '2022-08-13' '2022-08-04'
#  '2023-09-11' '2022-12-23' '2023-01-10' '2022-11-24' '2023-04-02'
#  '2022-09-19' '2023-10-17' '2023-12-27' '2023-01-03' '2022-08-22'
#  '2023-03-17' '2022-05-16' '2022-10-29' '2023-07-04' '2023-09-25'
#  '2023-02-27' '2022-10-18' '2022-11-03' '2023-01-01' '2023-06-09'
#  '2023-04-23' '2023-10-27' '2022-04-04' '2023-12-05' '2023-07-11'
#  '2023-04-04' '2022-04-25' '2023-08-09' '2023-08-11' '2023-03-26'
#  '2022-01-25' '2023-08-05' '2022-12-15' '2022-02-23' '2023-06-26'
#  '2022-07-03' '2023-08-31' '2023-12-23' '2023-12-12' '2022-03-02'
#  '2022-05-10' '2022-01-12' '2023-03-12' '2023-01-14' '2023-11-16'
#  '2023-05-25' '2023-07-14' '2023-11-24' '2022-05-19' '2023-11-08'
#  '2023-10-13' '2022-06-18' '2023-08-26' '2022-12-30' '2022-11-08'
#  '2023-01-29' '2022-11-21' '2022-02-21' '2022-10-24' '2022-09-25'
#  '2022-01-17' '2022-03-30' '2022-03-16' '2022-09-17' '2022-01-09'
#  '2023-10-03' '2022-06-26' '2022-04-23' '2023-01-12' '2022-11-25'
#  '2022-01-22' '2022-01-28' '2023-11-28' '2023-01-05' '2022-09-18'
#  '2022-10-15' '2022-11-10' '2023-07-18' '2022-06-11' '2023-09-13'
#  '2023-07-24' '2023-04-30' '2023-01-08' '2022-07-21' '2022-02-03'
#  '2022-03-08' '2022-09-05' '2022-08-25' '2022-12-04' '2022-06-10'
#  '2022-06-04' '2022-04-26' '2023-01-22' '2023-09-06' '2022-03-05'
#  '2022-02-04' '2022-09-13' '2022-12-12' '2022-05-04' '2023-10-01'
#  '2023-05-11' '2023-02-02' '2023-09-09' '2022-06-25' '2022-01-23'
#  '2022-12-01' '2023-08-08' '2022-02-17' '2022-09-24' '2022-10-19'
#  '2022-04-30' '2022-01-10' '2022-07-25' '2022-02-11' '2023-12-13'
#  '2022-12-10' '2023-01-24' '2022-04-28' '2022-03-03' '2022-08-24'
#  '2022-09-23' '2022-05-20' '2023-04-26' '2022-02-19' '2022-06-05'
#  '2023-11-07' '2022-12-13' '2023-08-16' '2022-10-30' '2023-01-25'
#  '2023-10-21' '2023-11-17' '2022-08-23' '2023-04-14' '2023-06-23'
#  '2023-06-20' '2023-07-19' '2023-12-19' '2022-08-17' '2022-09-21'
#  '2023-06-24' '2023-03-31' '2022-01-19' '2023-04-08' '2023-04-05'
#  '2023-05-15' '2023-04-09' '2023-01-07' '2022-01-04' '2022-04-09'
#  '2023-01-02' '2023-12-24' '2023-05-13' '2023-12-22' '2022-03-12'
#  '2023-12-29' '2023-06-06' '2022-12-26' '2023-08-19' '2022-11-11'
#  '2022-11-04' '2023-09-23' '2022-09-30' '2023-05-12' '2023-06-02'
#  '2023-12-31' '2022-03-10' '2023-11-03' '2023-07-26' '2022-03-14'
#  '2023-12-10' '2022-06-14' '2023-03-13' '2022-03-06' '2022-02-13'
#  '2023-03-20' '2022-08-16' '2022-07-07' '2023-02-06' '2023-09-07'
#  '2023-12-01' '2023-07-09' '2022-01-14' '2022-02-06' '2023-02-10'
#  '2022-11-18' '2022-12-27' '2022-06-17' '2023-12-20' '2023-06-21'
#  '2023-10-08' '2023-01-15' '2023-05-29' '2023-06-13' '2023-03-16'
#  '2022-07-05' '2022-09-07' '2022-05-06' '2022-01-21' '2023-08-21'
#  '2022-02-24' '2022-06-12' '2022-09-14' '2022-04-18' '2023-04-07'
#  '2022-04-21' '2023-09-04' '2022-07-12' '2022-02-20' '2022-11-02'
#  '2023-07-02' '2022-08-02' '2023-12-28' '2022-07-31' '2022-07-10'
#  '2022-04-27' '2022-08-14' '2023-07-03' '2023-04-29' '2023-01-27'
#  '2023-05-16' '2023-08-27' '2023-09-10' '2023-02-20' '2023-02-14'
#  '2023-08-07' '2023-11-02' '2023-06-03' '2022-06-15' '2023-07-05']

# %% [markdown]
# Untuk kolom Order Date, dapat dilihat diatas bahwa data nya sudah konsisten.

# %% [markdown]
# 4. Payment Method

# %%
print(df['Payment Method'].unique())
# Out:
# ['Credit Card' 'Digital Wallet' 'Cash' nan]

# %% [markdown]
# Untuk kolom Payment Method, dapat dilihat diatas bahwa data nya sudah konsisten meskipun terdapat data yang kosong.

# %% [markdown]
# ## Missing Values

# %% [markdown]
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada seluruh kolom. Dan terlihat bahwa kolom:
# * Item
#
# Memiliki missing values sekitar 10%, yang dimana ini perlu ditangani atau dihapus.
# * Price
#
# Memiliki missing values sekitar 5% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.
# * Quantity
#
# Memiliki missing values sekitar 2,5% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.
# * Order Total
#
# Memiliki missing values sekitar 2,5% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.
# * Payment Method
#
# Memiliki missing values sekitar 6% yang dimana hal ini perlu ditangani dengan cara mau ditangani atau dihapus.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                 Null Ratio in %
# Order ID               0.000000
# Customer ID            0.000000
# Category               0.000000
# Item                  10.026235
# Price                  4.996008
# Quantity               2.452378
# Order Total            2.452378
# Order Date             0.000000
# Payment Method         6.170868

# %% [markdown]
# ## Duplicated Values

# %% [markdown]
# Pada tahap ini, saya akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.
#
# dapat dilihat dibawah, bahwa dataset ini tidak memiliki duplikasi, oleh karena itu tidak diperlukan penanganan.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Customer ID, Category, Item, Price, Quantity, Order Total, Order Date, Payment Method]
# Index: []

# %% [markdown]
# ## Outliers Values

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data kan numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.
#
# Dan terlihat kolom
# * Price
#
# Dengan presentase 13%
# * Quantity
#
# Dengan presentase 0%
# * Order Total
#
# Dengan presentase 8%

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom        Persentase Outliers
# Price                  13.180107
# Quantity                0.000000
# Order Total             8.035816

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Price'])
plt.title('Boxplot of Price')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Order Total'])
plt.title('Boxplot of Order Total')
plt.ylabel('Order Total')
plt.show()

# %% [markdown]
# # Eksplorasi Data (EDA)

# %% [markdown]
# ## Comparasion/Perbandingan

# %% [markdown]
# - **Aktivitas**: Membandingkan total penjualan antar kategori menu, antar item menu teratas, dan tren penjualan berdasarkan periode waktu (tahun dan bulan).
# - **Tujuan**: Mengidentifikasi menu terlaris, kategori yang paling populer, serta periode waktu (musim, bulan) dengan penjualan tertinggi atau terendah untuk perencanaan stok dan strategi pemasaran.
# - **Visualisasi**: Bar Chart (Grafik Batang) untuk kategori, item, tahun dan bulan.

# %% [markdown]
# - Kategori 'Main Dishes' memiliki total penjualan tertinggi, jauh melampaui kategori lain, menunjukkan fokus utama dan popularitas menu utama di restoran ini.

# %%
penjualan_per_kategori = df.groupby('Category')['Order Total'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=penjualan_per_kategori.index, y=penjualan_per_kategori.values, palette='viridis', hue=penjualan_per_kategori.index, legend=False)
plt.title('Total Penjualan Berdasarkan Kategori Menu')
plt.xlabel('Kategori Menu')
plt.ylabel('Total Penjualan')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - 'Grilled Chicken' dan 'Pasta Alfredo' adalah dua item individu teratas yang paling laku, menandakan kedua menu ini sangat diminati pelanggan dan berkontribusi signifikan pada pendapatan.

# %%
penjualan_per_item = df.groupby('Item')['Order Total'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12, 7))
sns.barplot(x=penjualan_per_item.index, y=penjualan_per_item.values, palette='plasma', hue=penjualan_per_item.index, legend=False)
plt.title('Top 10 Item dengan Penjualan Tertinggi')
plt.xlabel('Item Menu')
plt.ylabel('Total Penjualan')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Penjualan di tahun 2022 sedikit lebih tinggi dibandingkan tahun 2023, menunjukkan stabilitas pendapatan dengan sedikit penurunan atau stagnasi pertumbuhan antar tahun.

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month_name()

sales_per_year = df.groupby('Year')['Order Total'].sum().sort_values(ascending=False)
plt.figure(figsize=(6, 5))
sns.barplot(x=sales_per_year.index, y=sales_per_year.values, palette='viridis', hue=sales_per_year.index, legend=False)
plt.title('Total Penjualan per Tahun')
plt.xlabel('Tahun')
plt.ylabel('Total Penjualan')
plt.show()

# %% [markdown]
# - Penjualan menunjukkan fluktuasi bulanan, dengan bulan Maret dan Agustus sebagai bulan-bulan dengan penjualan yang lebih tinggi, sementara bulan Februari dan November cenderung lebih rendah.

# %%
sales_per_month = df.groupby('Month')['Order Total'].sum().reindex(
    ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
)
plt.figure(figsize=(12, 6))
sns.barplot(x=sales_per_month.index, y=sales_per_month.values, palette='plasma', hue=sales_per_month.index, legend=False)
plt.title('Total Penjualan per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Total Penjualan')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Composition/Komposisi

# %% [markdown]
# - **Aktivitas**: Menentukan proporsi atau persentase total penjualan yang disumbangkan oleh setiap kategori menu dan setiap metode pembayaran.
# - **Tujuan**: Memahami seberapa besar kontribusi masing-masing bagian terhadap total keseluruhan, seperti dominasi kategori menu tertentu atau preferensi metode pembayaran pelanggan.
# - **Visualisasi**: Pie Chart (Grafik Lingkaran) untuk kategori menu dan metode pembayaran.

# %% [markdown]
# - 'Main Dishes' menyumbang hampir setengah (sekitar 49%) dari total pendapatan, diikuti oleh 'Starters' dan 'Desserts', menegaskan dominasi menu utama dalam struktur pendapatan.

# %%
penjualan_per_kategori_komposisi = df.groupby('Category')['Order Total'].sum()

plt.figure(figsize=(8, 8))
plt.pie(penjualan_per_kategori_komposisi, labels=penjualan_per_kategori_komposisi.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis'))
plt.title('Komposisi Total Penjualan Berdasarkan Kategori Menu')
plt.ylabel('')
plt.show()

# %% [markdown]
# - Proporsi total penjualan yang berasal dari 'Cash', 'Credit Card', dan 'Digital Wallet' relatif seimbang, menunjukkan tidak ada satu metode pembayaran yang mendominasi secara absolut, memberikan pilihan yang beragam bagi pelanggan.

# %%
penjualan_per_metode_pembayaran_komposisi = df.groupby('Payment Method')['Order Total'].sum()

plt.figure(figsize=(8, 8))
plt.pie(penjualan_per_metode_pembayaran_komposisi, labels=penjualan_per_metode_pembayaran_komposisi.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Komposisi Total Penjualan Berdasarkan Metode Pembayaran')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Distribution/Distribusi

# %% [markdown]
# - **Aktivitas**: Menganalisis sebaran nilai dari variabel numerik seperti harga item (Price) dan total pesanan (Order Total).
# - **Tujuan**: Memahami pola penyebaran data, mengidentifikasi nilai-nilai yang paling sering muncul, rentang nilai, serta mendeteksi adanya outlier atau anomali pada data harga dan total transaksi.
# - **Visualisasi**: Histogram (Grafik Frekuensi) untuk Price dan Order Total.

# %% [markdown]
# - Mayoritas item memiliki harga di bawah 7, dengan frekuensi tertinggi berada di kisaran 7, dengan frekuensi tertinggi berada di kisaran 3-5, mengindikasikan bahwa restoran menawarkan banyak pilihan menu dengan harga terjangkau.

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Price'].dropna(), kde=True)
plt.title('Distribusi Harga Item')
plt.xlabel('Harga')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# - Sebagian besar transaksi memiliki total pesanan di bawah 20, menunjukkan bahwa banyak pelanggan melakukan pembelian dalam jumlah kecil, namun ada beberapa transaksi besar yang mencapai 20, menunjukkan bahwa banyak pelanggan melakukan pembelian dalam jumlah kecil, namun ada beberapa transaksi besar yang mencapai 100.

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Order Total'].dropna(), kde=True)
plt.title('Distribusi Total Pesanan')
plt.xlabel('Total Pesanan')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ## Relationship/Hubungan

# %% [markdown]
# - **Aktivitas**: Menguji keterkaitan atau korelasi antara variabel-variabel numerik, seperti antara harga, kuantitas, dan total pesanan.
# - **Tujuan**: Menemukan apakah ada pengaruh satu variabel terhadap variabel lain, misalnya apakah harga yang lebih tinggi berkorelasi dengan total pesanan yang lebih besar, atau apakah kuantitas yang dibeli mempengaruhi total pesanan.
# - **Visualisasi**: Scatter Plot (Diagram Tebar) untuk melihat hubungan antar dua variabel, dan Heatmap (Peta Panas) untuk menampilkan matriks korelasi multi-variabel.

# %% [markdown]
# - Matriks korelasi menunjukkan bahwa harga item memiliki pengaruh yang sangat besar terhadap total pesanan (korelasi 0.79), sementara kuantitas memiliki pengaruh yang cukup signifikan (korelasi 0.50), keduanya berkontribusi positif pada nilai total transaksi.

# %%
correlation_matrix = df[['Price', 'Quantity', 'Order Total']].corr()
print('Matriks Korelasi:')
display(correlation_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap Korelasi Harga, Kuantitas, dan Total Pesanan')
plt.show()
# Out:
# Matriks Korelasi:
#                 Price  Quantity  Order Total
# Price        1.000000  0.007120     0.788138
# Quantity     0.007120  1.000000     0.502331
# Order Total  0.788138  0.502331     1.000000

# %% [markdown]
# # Menyimpan Dataset

# %%
df.to_csv('Restaurant Sales Data.csv', index=False)

# %% [markdown]
# # **Penanganan Untuk kolom bermasalah**

# %% [markdown]
# ## Tipe data

# %% [markdown]
# Hasil Verifikasi Kualitas Data :
# - (Penjelasan bisa dibaca di bagian "cek tipe data" diatas)

# %%
df.dtypes
# Out:
# Order ID                  object
# Customer ID               object
# Category                  object
# Item                      object
# Price                    float64
# Quantity                 float64
# Order Total              float64
# Order Date        datetime64[ns]
# Payment Method            object
# Year                       int32
# Month                     object
# dtype: object

# %% [markdown]
# ### Penanganan :

# %% [markdown]
# Order Date:

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Order Date']
# Out:
# 0       2023-12-21
# 1       2023-05-19
# 2       2023-09-27
# 3       2022-08-09
# 4       2022-05-15
#            ...
# 17529   2023-12-23
# 17530   2023-12-18
# 17531   2022-05-20
# 17532   2022-01-27
# 17533   2023-01-07
# Name: Order Date, Length: 17534, dtype: datetime64[ns]

# %% [markdown]
# Mengubah ke tipe datetime memungkinkan pandas untuk mengenali kolom tersebut sebagai data tanggal dan waktu, sehingga kita dapat dengan mudah melakukan berbagai operasi berbasis waktu yang sangat penting untuk analisis tren penjualan berdasarkan waktu.

# %% [markdown]
# ## Inconsistent Values

# %% [markdown]
# ### penanganan :

# %% [markdown]
# Pada Verifikasi Kualitas Data diatas, dapat dilihat bahwa tidak ada ketidak konsisten-an data. Jadi pada bagian ini, tidak ada yang perlu di tangani.

# %% [markdown]
# ## Missing Values

# %% [markdown]
# Hasil Verifikasi Kualitas Data :
# - (Penjelasan bisa dibaca di bagian "Missing Values" diatas)

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                 Null Ratio in %
# Order ID               0.000000
# Customer ID            0.000000
# Category               0.000000
# Item                  10.026235
# Price                  4.996008
# Quantity               2.452378
# Order Total            2.452378
# Order Date             0.000000
# Payment Method         6.170868
# Year                   0.000000
# Month                  0.000000

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Price'].dropna(), bins=20, kde=True)
plt.title('Distribusi Price')
plt.xlabel('Price')
plt.ylabel('Frekuensi')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Quantity'].dropna(), bins=20, kde=True)
plt.title('Distribusi Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frekuensi')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Order Total'].dropna(), bins=20, kde=True)
plt.title('Distribusi Order Total')
plt.xlabel('Order Total')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ### Penanganan :

# %% [markdown]
# Item :

# %%
df['Item'] = df['Item'].fillna(df['Item'].dropna().mode()[0])

# %% [markdown]
# Price :

# %%
df['Price'] = df['Price'].fillna(df['Price'].dropna().median())

# %% [markdown]
# Quantity :

# %%
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].dropna().median())

# %% [markdown]
# Order Total :

# %%
df['Order Total'] = df['Order Total'].fillna(df['Order Total'].dropna().median())

# %% [markdown]
# Payment Method :

# %%
df['Payment Method'] = df['Payment Method'].fillna(df['Payment Method'].dropna().mode()[0])

# %% [markdown]
# Item dan Payment Method : Modus digunakan untuk data kategorikal karena tidak ada konsep 'rata-rata' atau 'median' yang berlaku.

# %% [markdown]
# Price, Quantity, dan Order Total : Median dipilih karena pada tahap awal describe() dan visualisasi histogram, terlihat bahwa distribusi ketiga kolom ini cenderung skewed (condong ke satu sisi) atau memiliki outliers. Median lebih robust terhadap outliers dibandingkan dengan mean, sehingga lebih merepresentasikan nilai 'tipikal' dari data yang ada.

# %% [markdown]
# Cek :

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                 Null Ratio in %
# Order ID                    0.0
# Customer ID                 0.0
# Category                    0.0
# Item                        0.0
# Price                       0.0
# Quantity                    0.0
# Order Total                 0.0
# Order Date                  0.0
# Payment Method              0.0
# Year                        0.0
# Month                       0.0

# %% [markdown]
# Nilai yang hilang dapat menyebabkan kesalahan dalam perhitungan statistik, visualisasi yang tidak akurat, atau bahkan membuat beberapa analisis tidak bisa dilakukan. Mengisi nilai yang hilang (imputasi) memungkinkan untuk menggunakan seluruh baris data tanpa menghilangkan informasi yang berharga.

# %% [markdown]
# ## Duplicated Values

# %% [markdown]
# ### penanganan

# %% [markdown]
# Pada Verifikasi kualitas data diatas, dapat dilihat bahwa tidak ada duplikasi data. Jadi, pada bagian ini tidak ada yang perlu ditangani.

# %% [markdown]
# ## Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom        Persentase Outliers
# Price                  19.219802
# Quantity                0.000000
# Order Total             8.338086

# %% [markdown]
# ### Penanganan :

# %% [markdown]
# Price :

# %% [markdown]
# Pada kolom price/harga, sangat memungkinkan jika memiliki nilai yang outliers karena namanya harga pasti ada yang nilai nya jauh lebih tinggi atau rendah. jadi kolom ini tidak perlu ditangani

# %% [markdown]
# Order Total :

# %% [markdown]
# Pada kolom order total, sama seperti price, memang memungkinkan jika terdapat nilai outliers, karena pasti ada customer yang memborong, yang berdampak pada adanya outlier. Oleh karena itu, kolom ini tidak perlu ditangani.

# %% [markdown]
#  Untuk kedua kolom ini, outliers dianggap wajar dalam konteks bisnis restoran. Harga menu memang bervariasi, dan total pesanan bisa sangat tinggi jika ada pelanggan yang memborong atau memesan untuk rombongan besar. Menghapus atau mengubah outliers ini justru bisa menghilangkan informasi berharga mengenai variasi harga atau potensi pesanan besar yang terjadi secara alami dalam bisnis. Oleh karena itu, diputuskan untuk membiarkan outliers ini apa adanya karena dianggap merepresentasikan realitas bisnis.

# %% [markdown]
# # Contruct Data

# %%
def categorize_Order_Total(Order_Total):
    if Order_Total > 20:
        return 'Memborong'
    elif Order_Total < 20:
        return 'Tidak Memborong'
    else:
        return 'Anomali'

df['Order Status'] = df['Order Total'].apply(categorize_Order_Total)

# %%
df.head()
# Out:
#      Order ID Customer ID     Category             Item  Price  Quantity  \
# 0  ORD_705844    CUST_092  Side Dishes       Side Salad    3.0       1.0
# 1  ORD_338528    CUST_021  Side Dishes  Mashed Potatoes    4.0       3.0
# 2  ORD_443849    CUST_029  Main Dishes  Grilled Chicken   15.0       4.0
# 3  ORD_630508    CUST_075       Drinks    Pasta Alfredo    5.0       2.0
# 4  ORD_648269    CUST_031  Main Dishes    Pasta Alfredo   12.0       4.0
#
#    Order Total Order Date  Payment Method  Year      Month     Order Status
# 0          3.0 2023-12-21     Credit Card  2023   December  Tidak Memborong
# 1         12.0 2023-05-19  Digital Wallet  2023        May  Tidak Memborong
# 2         60.0 2023-09-27     Credit Card  2023  September        Memborong
# 3          5.0 2022-08-09     Credit Card  2022     August  Tidak Memborong
# 4         48.0 2022-05-15            Cash  2022        May        Memborong

# %% [markdown]
# Penggunaan kolom Order Status yang baru sangat bermanfaat karena memungkinkan segmentasi pelanggan yang lebih jelas, sehingga restoran dapat merancang strategi promosi yang lebih tepat sasaran, mengoptimalkan pengelolaan stok berdasarkan pola pembelian, dan meningkatkan efektivitas analisis bisnis secara keseluruhan dengan mengubah data total pesanan numerik menjadi kategori yang bermakna.

# %% [markdown]
# # Data Reduction

# %%
df = df.drop(columns=['Month'])

# %%
df.head()
# Out:
#      Order ID Customer ID     Category             Item  Price  Quantity  \
# 0  ORD_705844    CUST_092  Side Dishes       Side Salad    3.0       1.0
# 1  ORD_338528    CUST_021  Side Dishes  Mashed Potatoes    4.0       3.0
# 2  ORD_443849    CUST_029  Main Dishes  Grilled Chicken   15.0       4.0
# 3  ORD_630508    CUST_075       Drinks    Pasta Alfredo    5.0       2.0
# 4  ORD_648269    CUST_031  Main Dishes    Pasta Alfredo   12.0       4.0
#
#    Order Total Order Date  Payment Method  Year     Order Status
# 0          3.0 2023-12-21     Credit Card  2023  Tidak Memborong
# 1         12.0 2023-05-19  Digital Wallet  2023  Tidak Memborong
# 2         60.0 2023-09-27     Credit Card  2023        Memborong
# 3          5.0 2022-08-09     Credit Card  2022  Tidak Memborong
# 4         48.0 2022-05-15            Cash  2022        Memborong

# %% [markdown]
# Bertujuan untuk menyederhanakan dan merampingkan dataset. Dengan mengurangi jumlah dimensi data, analisis menjadi lebih fokus dan efisien, karena menghilangkan informasi yang tidak relevan dapat mempercepat pemrosesan dan membantu mengidentifikasi pola penting tanpa 'kebisingan' data yang tidak diperlukan, sehingga menghasilkan wawasan yang lebih sesuai dengan kebutuhan studi kasus Anda.

# %% [markdown]
# # Menyimpan Dataset(bersih)

# %%
df.to_csv('[Bersih]Restaurant Sales Data.csv', index=False)

# %% [markdown]
# # Visualisasi

# %% [markdown]
# ## Barchart

# %%
plt.figure(figsize=(12, 7))
sns.countplot(x='Category', hue='Payment Method', data=df, palette='viridis')
plt.title('Distribusi Top 5 Categories Berdasarkan Payment Method')
plt.xlabel('Category')
plt.ylabel('Order Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Analisis diagram batang menunjukkan bahwa 'Main Dishes' mendominasi jumlah pesanan secara keseluruhan, memperkuat posisinya sebagai pendorong pendapatan utama restoran. Distribusi metode pembayaran (Kartu Kredit, Dompet Digital, Tunai) relatif seimbang di seluruh kategori teratas, meskipun terdapat sedikit preferensi terhadap Kartu Kredit dan Dompet Digital untuk 'Main Dishes' dan 'Starters', mengindikasikan nilai kenyamanan dan transaksi yang mungkin lebih tinggi. Hal ini menyiratkan bahwa bisnis inti restoran sangat bergantung pada hidangan utama, dengan preferensi pembayaran yang seimbang namun sedikit condong ke arah cashless untuk pesanan yang lebih besar. Oleh karena itu, agar restoran terus mengoptimalkan pengalaman 'Main Dishes' melalui kualitas dan inovasi yang konsisten, serta mempertimbangkan promosi metode pembayaran yang ditargetkan untuk hidangan utama dan appetizer guna mendorong penggunaan cashless dan meningkatkan nilai pesanan.

# %% [markdown]
# ## Piechart

# %%
plt.figure(figsize=(10, 6))
plt.pie(df['Payment Method'].value_counts(), labels=df['Payment Method'].value_counts().index, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Komposisi Metode Pembayaran')
plt.show()

# %% [markdown]
# Analisis pie chart menunjukkan bahwa 'Credit Card' adalah metode pembayaran paling sering digunakan (36.6%), diikuti 'Digital Wallet' (33.0%) dan 'Cash' (30.4%), menandakan tidak ada dominasi absolut tetapi ada sedikit preferensi non-tunai. Mayoritas transaksi (69.6%) menggunakan metode non-tunai, menunjukkan tren modernisasi dan kenyamanan bagi pelanggan. Meskipun 'Credit Card' memiliki sedikit keunggulan, keseimbangan yang sehat antar metode pembayaran menyiratkan bahwa restoran berhasil melayani preferensi beragam pelanggan. Rekomendasi tindakan meliputi optimasi infrastruktur non-tunai, promosi bertarget untuk 'Digital Wallet' atau 'Cash' untuk pemerataan distribusi, survei kepuasan pembayaran, dan edukasi penggunaan metode digital untuk mempermudah transisi.

# %% [markdown]
# ## Linechart

# %%
orders_per_year = df.groupby('Year').size().reset_index(name='Number of Orders')

plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Number of Orders', data=orders_per_year, marker='o')
plt.title('Total Orders per Year')
plt.xlabel('Tahun')
plt.ylabel('Jumlah Orders')
plt.grid(True)
plt.xticks(orders_per_year['Year'].unique())
plt.show()

# %% [markdown]
# Analisis diagram garis 'Total Number of Orders per Year' menunjukkan bahwa terjadi penurunan jumlah pesanan dari tahun 2022 ke tahun 2023. Pada tahun 2022, restoran menerima 8906 pesanan, sedangkan pada tahun 2023, jumlah pesanan sedikit menurun menjadi 8628. Penurunan ini meskipun tidak drastis, mengindikasikan adanya potensi stagnasi atau sedikit penurunan minat pelanggan. Untuk mengatasi penurunan ini dan mendorong pertumbuhan, restoran dapat meluncurkan kampanye pemasaran yang ditargetkan untuk menarik pelanggan baru dan mempertahankan pelanggan lama. Selain itu, inovasi menu dengan memperkenalkan hidangan baru atau penawaran khusus dapat membangkitkan kembali minat dan meningkatkan volume pesanan.

# %% [markdown]
# ## Histogram

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Order Total'].dropna(), kde=True)
plt.title('Distribusi Total Pesanan')
plt.xlabel('Total Pesanan')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Analisis histogram menunjukkan bahwa mayoritas item restoran memiliki harga terjangkau, berkisar antara 3-7 dengan puncak di sekitar 5, mengindikasikan banyak pilihan ekonomis. Sebagian besar transaksi memiliki total pesanan di bawah 20, dengan frekuensi tinggi antara $5-$15, meskipun ada beberapa transaksi besar hingga $100. Distribusi keduanya cenderung right skewed, menandakan keberadaan item premium dan pesanan bervolume tinggi yang, meskipun tidak sering, berkontribusi signifikan. Oleh karena itu, restoran memiliki kesempatan untuk mempertahankan penawaran terjangkau, sekaligus mengembangkan strategi untuk upselling dan cross-selling item premium atau paket makan keluarga/grup untuk meningkatkan nilai transaksi rata-rata, dengan fokus pada titik harga populer dan program promosi yang sesuai.

# %% [markdown]
# ## Boxplot

# %%
top_5_categories = df['Category'].value_counts().head(5).index
filtered_df = df[df['Category'].isin(top_5_categories)]

plt.figure(figsize=(12, 7))
sns.boxplot(x='Category', y='Order Total', data=filtered_df, palette='viridis', order=top_5_categories, hue='Category', legend=False)
plt.title('Distribusi Total Pesanan per Kategori Menu', fontsize=16)
plt.xlabel('Kategori Menu', fontsize=12)
plt.ylabel('Total Pesanan', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Analisis boxplot distribusi total pesanan per kategori menu menunjukkan bahwa 'Main Dishes' memiliki nilai median total pesanan tertinggi dan rentang interkuartil yang luas, mengindikasikan variasi pesanan yang signifikan dan potensi pendapatan tinggi. Sementara itu, 'Side Dishes' dan 'Drinks' cenderung memiliki median total pesanan yang lebih rendah dan rentang yang lebih sempit, menunjukkan pesanan dengan nilai lebih kecil dan kurang bervariasi. Outlier yang signifikan pada 'Main Dishes' dan 'Starters' menandakan adanya transaksi bernilai sangat tinggi yang, meskipun jarang, berkontribusi besar pada pendapatan. Dari insight ini, restoran direkomendasikan untuk fokus pada strategi upselling dan cross-selling untuk 'Main Dishes' dan 'Starters' guna meningkatkan frekuensi pesanan bernilai tinggi, serta mengembangkan paket kombo atau promosi untuk 'Side Dishes' dan 'Drinks' agar dapat meningkatkan total pesanan kumulatif dari kategori dengan nilai transaksi individu yang lebih rendah.

# %% [markdown]
# ## Scatterplot

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Price', y='Order Total', alpha=0.6)
plt.title('ScatterPlot Price dan Order Total')
plt.xlabel('Price')
plt.ylabel('Order Total')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Quantity', y='Order Total', alpha=0.6)
plt.title('ScatterPlot Quantity dan Order Total')
plt.xlabel('Quantity')
plt.ylabel('Order Total')
plt.grid(True)
plt.show()

# %% [markdown]
# Analisis data menunjukkan bahwa baik harga item maupun kuantitas yang dibeli memiliki korelasi positif yang kuat dengan total pesanan. Mayoritas transaksi melibatkan item berharga lebih rendah dan kuantitas kecil hingga menengah (1-5 item), yang menghasilkan total pesanan yang lebih kecil. Namun, penjualan item berharga tinggi secara langsung mendorong peningkatan pendapatan per pesanan. Untuk memaksimalkan pendapatan, restoran dapat mengoptimalkan item menu bernilai tinggi dengan menjaga kualitas, serta menerapkan strategi upselling dan cross-selling. Selain itu, promosi paket keluarga atau kombo, diskon berjenjang untuk pembelian kuantitas lebih tinggi, visualisasi porsi yang menarik, optimasi ukuran porsi, dan program loyalitas berbasis kuantitas dapat mendorong pelanggan untuk membeli lebih banyak, sehingga meningkatkan nilai total pesanan.

# %% [markdown]
# ## Bubblechart

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Order Total', y='Price', size='Quantity', hue='Category', data=df, sizes=(50, 1000), alpha=0.7, palette='viridis')
plt.title('Hubungan Harga, Kuantitas, dan Kategori terhadap Total Pesanan', fontsize=16)
plt.xlabel('Total Pesanan', fontsize=12)
plt.ylabel('Harga Item', fontsize=12)
plt.grid(True)
plt.legend(title='Kategori', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Analisis bubble chart yang memvisualisasikan hubungan antara Total Pesanan (sumbu X), Harga Item (sumbu Y), Kuantitas (ukuran bubble), dan Kategori (warna bubble) menunjukkan bahwa kategori 'Main Dishes' seringkali terkait dengan bubble yang lebih besar (kuantitas lebih tinggi) dan Total Pesanan yang lebih besar, terutama untuk item dengan harga menengah hingga tinggi. Hal ini mengindikasikan bahwa 'Main Dishes' adalah pendorong utama volume dan nilai transaksi. Kategori lain seperti 'Drinks' dan 'Side Dishes' umumnya menunjukkan bubble yang lebih kecil dan Total Pesanan yang lebih rendah, mencerminkan sifatnya sebagai pelengkap. Dari insight ini, restoran direkomendasikan untuk terus menekankan kualitas dan promosi 'Main Dishes' sebagai inti pendapatan, sekaligus mengembangkan strategi bundling atau kombo yang menarik untuk 'Side Dishes' dan 'Drinks' bersama 'Main Dishes' guna meningkatkan kuantitas pesanan dan Total Pesanan secara keseluruhan, serta mengidentifikasi peluang untuk item premium dalam kategori pelengkap yang dapat meningkatkan harga per item.

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            fmt='.2f')
plt.title('Heatmap Korelasi Harga, Kuantitas, dan Total Pesanan')
plt.show()

# %% [markdown]
# Analisis heatmap korelasi menunjukkan bahwa 'Price' (Harga) memiliki korelasi positif yang sangat kuat (0.79) dengan 'Order Total' (Total Pesanan), mengindikasikan bahwa item dengan harga lebih tinggi secara langsung meningkatkan nilai total transaksi. 'Quantity' (Kuantitas) juga menunjukkan korelasi positif yang signifikan (0.50) dengan 'Order Total', menegaskan bahwa lebih banyak item yang dibeli akan menghasilkan total pesanan yang lebih tinggi. Korelasi antara 'Price' dan 'Quantity' sangat rendah (0.01), yang berarti harga item tidak terlalu mempengaruhi berapa banyak item yang dibeli dalam satu transaksi. Untuk memaksimalkan pendapatan, restoran harus fokus pada strategi ganda: pertama, mengoptimalkan menu dan promosi untuk item berharga tinggi (misalnya, melalui upselling atau penawaran premium) karena dampaknya langsung pada total pesanan; kedua, mendorong pembelian dalam jumlah lebih besar melalui paket kombo, diskon kuantitas, atau program loyalitas, mengingat kontribusi signifikan kuantitas terhadap total pesanan.

# %% [markdown]
# # Menyimpan Dataset(bersih)

# %%
df.to_csv('[Bersih]Restaurant Sales Data.csv', index=False)
